# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import os.path

# %matplotlib inline

# %%
file = '/Users/yana/PycharmProjects/untitled/names/'

# %% [markdown]
# Задание 1

# %%
names_by_year = {}
colns = ['Name','Gender','Count']
for year in range(1900, 2001, 1):
    names_by_year[year] = pd.read_csv(os.path.join(file, "yob{}.txt".format(year)), names=colns)
names_all = pd.concat(names_by_year, names=['Year', 'Pos'])

# %%
name_dynamics = names_all.groupby([names_all.index.get_level_values(0), 'Name']).sum()
name_dynamics.query('Name == ["Ruth", "Robert"]').unstack('Name').plot()

# %%
names_by_year = {}
for year in range(1900, 2001, 5):
    names_by_year[year] = pd.read_csv(os.path.join(file, "yob{}.txt".format(year)), names=colns)
names_all = pd.concat(names_by_year, names=['Year', 'Pos'])
name_dynamics = names_all.groupby([names_all.index.get_level_values(0), 'Name']).sum()

# %%
name_dynamics.query('Name == ["Ruth", "Robert"]').unstack('Name').plot.bar()

# %%
names_by_year = {}
years = [1950]
for year in years:
    names_by_year[year] = pd.read_csv(os.path.join(file, "yob{}.txt".format(year)), names=colns)
names_all = pd.concat(names_by_year, names=['Year', 'Pos'])

# %%
names_all.groupby('Name').sum().filter(like='R', axis=0).plot.pie(y='Count')

# %%
names_all.groupby('Name').sum().sort_values(by='Count', ascending=False).head(5).plot.pie(y='Count')

# %%
7136 + 4960
# Out:
# 12096

# %%
names_by_year = {}
for year in range(1900, 2001, 5):
    names_by_year[year] = pd.read_csv(os.path.join(file, "yob{}.txt".format(year)), names=colns)
names_all = pd.concat(names_by_year, names=['Year', 'Pos'])
names_all['let'] = names_all['Name'].replace(r"[aeiouyAEIOUY]", "", regex=True)

# %%
names_all
# Out:
#                  Name Gender  Count    let
# Year Pos
# 1900 0           Mary      F  16707     Mr
#      1          Helen      F   6343    Hln
#      2           Anna      F   6114     nn
#      3       Margaret      F   5304  Mrgrt
#      4           Ruth      F   4765    Rth
#      5      Elizabeth      F   4096  lzbth
#      6       Florence      F   3920  Flrnc
#      7          Ethel      F   3896    thl
#      8          Marie      F   3856     Mr
#      9        Lillian      F   3414   Llln
#      10         Annie      F   3324     nn
#      11          Edna      F   3102     dn
#      12          Emma      F   3095     mm
#      13         Alice      F   3059     lc
#      14        Bessie      F   3044    Bss
#      15        Bertha      F   3019   Brth
#      16         Grace      F   2942    Grc
#      17          Rose      F   2845     Rs
#      18         Clara      F   2826    Clr
#      19       Mildred      F   2800  Mldrd
# ...
