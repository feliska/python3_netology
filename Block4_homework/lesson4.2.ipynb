# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import os.path

# %matplotlib inline

# %%
file = '/Users/felis/PycharmProjects/netology/names'

# %% [markdown]
# ## Задание 1

# %%
names_by_year = {}
colns = ['Name','Gender','Count']
for year in range(1900, 2001):
    names_by_year[year] = pd.read_csv(os.path.join(file, "yob{}.txt".format(year)), names=colns)
names_all = pd.concat(names_by_year, names=['Year', 'Pos'])

# %%
name_dynamics = names_all.groupby([names_all.index.get_level_values(0), 'Name']).sum()
name_dynamics.query('Name == ["Ruth", "Robert"]').unstack('Name').plot()

# %% [markdown]
# ## Задание 2

# %%
names_by_year = {}
for year in range(1900, 2001, 5):
    names_by_year[year] = pd.read_csv(os.path.join(file, "yob{}.txt".format(year)), names=colns)
names_all = pd.concat(names_by_year, names=['Year', 'Pos'])
name_dynamics = names_all.groupby([names_all.index.get_level_values(0), 'Name']).sum()

# %%
name_dynamics.query('Name == ["Ruth", "Robert"]').unstack('Name').plot.bar()

# %% [markdown]
# ## Задание 3

# %%
names_by_year = {}
years = [1950]
for year in years:
    names_by_year[year] = pd.read_csv(os.path.join(file, "yob{}.txt".format(year)), names=colns)
names_all = pd.concat(names_by_year, names=['Year', 'Pos'])

# %%
names_all.groupby('Name').sum().filter(like='R', axis=0).plot.pie(y='Count')

# %% [markdown]
# ## Задание 4

# %%
names_by_year = {}
for year in range(1900, 2001):
    names_by_year[year] = pd.read_csv(os.path.join(file, "yob{}.txt".format(year)), names=colns).groupby('Name').sum()
names_all = pd.concat(names_by_year, names=['Year'])
names_all
#names_all['letter'] = names_all['Name'].replace(r"[aeiouyAEIOUY]", "", regex=True)
# Out:
#                Count
# Year Name
# 1900 Aaron       103
#      Abbie       112
#      Abby          7
#      Abe          56
#      Abel         15
#      Abigail      14
#      Abner        21
#      Abraham     100
#      Abram        18
#      Abron         5
#      Ace           8
#      Acie         10
#      Acy           6
#      Ada        1101
#      Adabelle      5
#      Adah         37
#      Adaline      18
#      Adam        111
#      Adda         10
#      Addie       551
#      Addison      11
#      Adel          8
#      Adela        38
#      Adelaida      8
#      Adelaide    183
#      Adelard       6
#      Adelbert      7
#      Adele       186
#      Adelia       50
#      Adelina      19
# ...              ...
# 2000 Zyanna       17
#      Zyanne       12
#      Zyanya       15
#      Zyaria        7
#      Zyasia       20
#      Zyier         5
#      Zyion        11
#      Zykee         6
#      Zykeia        5
#      Zykeith       7
#      Zykeria      54
#      Zykeriah      5
#      Zykerria     12
#      Zykia        38
#      Zykiera       5
#      Zykira       10
#      Zyla         10
#      Zyler        13
#      Zymir         8
#      Zynia        11
#      Zyniah        7
#      Zyon         78
#      Zyonna        5
#      Zyquan       13
#      Zyra          5
#      Zyria        21
#      Zyron        12
#      Zyshaun       6
#      Zyshawn      10
#      Zyshonne     17
#
# [1187370 rows x 1 columns]

# %%
names_all.query('Name =="Aaron"')
# Out:
#             Count
# Year Name
# 1900 Aaron    103
# 1901 Aaron     80
# 1902 Aaron     78
# 1903 Aaron     93
# 1904 Aaron    117
# 1905 Aaron     96
# 1906 Aaron     96
# 1907 Aaron    130
# 1908 Aaron    114
# 1909 Aaron    142
# 1910 Aaron    145
# 1911 Aaron    187
# 1912 Aaron    303
# 1913 Aaron    417
# 1914 Aaron    490
# 1915 Aaron    553
# 1916 Aaron    588
# 1917 Aaron    601
# 1918 Aaron    663
# 1919 Aaron    645
# 1920 Aaron    668
# 1921 Aaron    697
# 1922 Aaron    705
# 1923 Aaron    626
# 1924 Aaron    682
# 1925 Aaron    657
# 1926 Aaron    600
# 1927 Aaron    552
# 1928 Aaron    560
# 1929 Aaron    475
# ...           ...
# 1971 Aaron   8477
# 1972 Aaron   7923
# 1973 Aaron   9318
# 1974 Aaron  10603
# 1975 Aaron  10670
# 1976 Aaron  11503
# 1977 Aaron  11780
# 1978 Aaron  12471
# 1979 Aaron  13219
# 1980 Aaron  13345
# 1981 Aaron  14842
# 1982 Aaron  14563
# 1983 Aaron  14629
# 1984 Aaron  13536
# 1985 Aaron  13272
# 1986 Aaron  12825
# 1987 Aaron  12821
# 1988 Aaron  14528
# 1989 Aaron  15413
# 1990 Aaron  14634
# 1991 Aaron  14341
# 1992 Aaron  14597
# 1993 Aaron  13933
# 1994 Aaron  14485
# 1995 Aaron  13371
# 1996 Aaron  12049
# 1997 Aaron  11234
# 1998 Aaron  10603
# 1999 Aaron   9902
# 2000 Aaron   9586
#
# [101 rows x 1 columns]

# %%
names_all['Count_len'] = names_all.apply(lambda row: len(row.let), axis=1)

# %%
names_all.groupby('Name').sum('Count')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-73c4e29cdf58> in <module>()
# ----> 1 names_all.groupby('Name').sum('Count')
#
# TypeError: f() takes 1 positional argument but 2 were given

# %%
def scatter_len(group):
    plt.plot(group['Count_len'], group['Count'], 'o', label=group.name)
    
names_all.groupby('Name').apply(scatter_len)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1, 4):
    print(i)
# Out:
# 1
# 2
# 3
